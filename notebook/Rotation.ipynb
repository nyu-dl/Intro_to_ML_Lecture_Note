# %%
# %matplotlib notebook 

import numpy
import matplotlib.pyplot as plot

# %%
import matplotlib
matplotlib.rc('text', usetex=True)

# %%
numpy.random.seed(1234)

# %%
def label_map(y_, from_, to_):
    y = numpy.copy(y_)
    for f in from_:
        y[y_ == f] = to_
    return y

# %%
from sklearn.datasets import make_blobs
n_dim = 2
x_tra, y_tra = make_blobs(n_samples=100, n_features=n_dim, centers=[[1,1],[-1,-1],[1,-1],[-1,1]], shuffle=True, cluster_std=0.3)

y_tra = label_map(y_tra, [0, 1], 0)
y_tra = label_map(y_tra, [2, 3], 1)

# %%
theta = numpy.radians(45)
c, s = numpy.cos(theta), numpy.sin(theta)
R = numpy.array([[c, -s], [s, c]])

# %%
x_r = numpy.dot(x_tra, R)
x_ra = abs(x_r)

# %%
# visualize data 
def vis_data(x, y, c='r'):
    plot.hold('on')
    for x_, y_ in zip(x, y):
        plot.plot(x_[0], x_[1], c+'o' if y_ == 0 else c+'+')
    plot.hold('off')
    plot.grid('on')

# %%
plot.figure()

plot.subplot(1,3,1)
vis_data(x_tra, y_tra, c='r')
plot.title('XOR (Original)')
plot.tight_layout()

plot.subplot(1,3,2)
vis_data(x_r, y_tra, c='r')
plot.title('XOR (Rotated)')
plot.tight_layout()

plot.subplot(1,3,3)
vis_data(x_ra, y_tra, c='r')
plot.title('XOR (Rotated+Abs)')
plot.tight_layout()

plot.tight_layout()
plot.show()
# Out:
# <img src="data:image/png;base64,..." width="998">
# /Users/kyunghyuncho/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   app.launch_new_instance()
# /Users/kyunghyuncho/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %%
plot.savefig('../figures/xor_transform.pdf', dpi=100, bbox_inches='tight')

# %%
print theta
# Out:
# 0.785398163397

# %%
x_tra.shape
# Out:
# (100, 2)

# %%
type(x_tra)
# Out:
# numpy.ndarray

# %%
x_tra[0]
# Out:
# array([ 1.00676543, -0.87490364])
