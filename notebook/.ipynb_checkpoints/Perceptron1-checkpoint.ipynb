# %%
# %matplotlib notebook 

import numpy
import matplotlib.pyplot as plot

# %%
import matplotlib
matplotlib.rc('text', usetex=True)

# %%
numpy.random.seed(1234)

# %%
# data set generation
n_dim = 2
n_mean = numpy.array([0., -1.])
n_cov = numpy.diag([0.2, .5])
p_mean = numpy.array([1., 1.])
p_cov = numpy.diag([.5, .3])

# generate postive examples
n_pos = 50
pos_y = numpy.ones(n_pos) 
pos_x = numpy.random.randn(n_pos, n_dim) * numpy.diag(p_cov)[None, :] + p_mean[None,:]
# generate negative examples
n_neg = 50
neg_y = numpy.zeros(n_neg)
neg_x = numpy.random.randn(n_neg, n_dim) * numpy.diag(n_cov)[None, :] + n_mean[None,:]
# combine them
y = numpy.concatenate([pos_y, neg_y])
x = numpy.concatenate([pos_x, neg_x], axis=0)
# shuffle them
si = numpy.random.permutation(n_pos + n_neg)
y = y[si]
x = x[si]

# grab training examples
n_tra = numpy.round(0.5 * (n_pos + n_neg)).astype(numpy.int)

y_tra = y[:n_tra]
x_tra = x[:n_tra]

y_tes = y[n_tra:]
x_tes = x[n_tra:]

# %%
def perceptron(x, w, pre=False):
    def sign(y):
        return numpy.maximum(0., numpy.sign(y))
    
    x = x.reshape([1, -1]) if len(x.shape) < 2 else x
    
    y = numpy.sum(x * w[None,:-1], axis=1) + w[-1]
    if pre:
        return y    
    return sign(y)

# %%
def perceptron_dist(y, x, w, avg=False):
    y_ = perceptron(x, w)
    d = -(y - y_) * perceptron(x, w, pre=True)
    if not avg:
        return d
    return numpy.mean(d)

# %%
def perceptron_rule(y, x, w):
    y_ = perceptron(x, w)
    dw = numpy.zeros(w.shape)
    dw[:-1] = numpy.mean((y_tra - y_)[:, None] * x, axis=0)
    dw[-1] = numpy.mean(y_tra - y_)
    return dw

# %%
w0 = numpy.random.randn(n_dim+1); w0[-1] = 0.
w = numpy.copy(w0)

n_iter = 1000
eta = .1
old_cost = numpy.Inf
for ni in xrange(n_iter):
    pred_y = perceptron(x_tra, w)
    w += eta * perceptron_rule(y_tra, x_tra, w)
    cost = perceptron_dist(y_tra, x_tra, w, avg=True)
    print 'Perceptron cost {} after iteration {}'.format(cost, ni)
    if cost < 1e-16 or cost / old_cost >= 1.:
        print 'Converged'
        break
    old_cost = cost
# Out:
# Perceptron cost 0.582551655216 after iteration 0
# Perceptron cost 0.527837500728 after iteration 1
# Perceptron cost 0.478664151755 after iteration 2
# Perceptron cost 0.43380638658 after iteration 3
# Perceptron cost 0.39645853255 after iteration 4
# Perceptron cost 0.36091859605 after iteration 5
# Perceptron cost 0.333059742832 after iteration 6
# Perceptron cost 0.30813222108 after iteration 7
# Perceptron cost 0.283204699329 after iteration 8
# Perceptron cost 0.258277177578 after iteration 9
# Perceptron cost 0.234337507554 after iteration 10
# Perceptron cost 0.212998375354 after iteration 11
# Perceptron cost 0.195504710423 after iteration 12
# Perceptron cost 0.185710587815 after iteration 13
# Perceptron cost 0.178359758926 after iteration 14
# Perceptron cost 0.171487782816 after iteration 15
# Perceptron cost 0.166014329959 after iteration 16
# Perceptron cost 0.160543874014 after iteration 17
# Perceptron cost 0.155464596404 after iteration 18
# Perceptron cost 0.150385318794 after iteration 19
# Perceptron cost 0.145306041184 after iteration 20
# Perceptron cost 0.140683261194 after iteration 21
# Perceptron cost 0.136878142435 after iteration 22
# Perceptron cost 0.133073023676 after iteration 23
# Perceptron cost 0.129267904917 after iteration 24
# Perceptron cost 0.125462786157 after iteration 25
# Perceptron cost 0.121657667398 after iteration 26
# Perceptron cost 0.117852548639 after iteration 27
# Perceptron cost 0.11404742988 after iteration 28
# Perceptron cost 0.110242311121 after iteration 29
# Perceptron cost 0.106437192361 after iteration 30
# Perceptron cost 0.103019279507 after iteration 31
# Perceptron cost 0.100467838922 after iteration 32
# Perceptron cost 0.0980644910301 after iteration 33
# Perceptron cost 0.0963499513576 after iteration 34
# Perceptron cost 0.094635411685 after iteration 35
# Perceptron cost 0.0929208720124 after iteration 36
# Perceptron cost 0.0912063323399 after iteration 37
# Perceptron cost 0.0894917926673 after iteration 38
# Perceptron cost 0.0877772529948 after iteration 39
# Perceptron cost 0.0860627133222 after iteration 40
# Perceptron cost 0.0843481736496 after iteration 41
# Perceptron cost 0.0826336339771 after iteration 42
# Perceptron cost 0.0809190943045 after iteration 43
# Perceptron cost 0.079204554632 after iteration 44
# Perceptron cost 0.0774900149594 after iteration 45
# Perceptron cost 0.0757754752868 after iteration 46
# Perceptron cost 0.0740609356143 after iteration 47
# Perceptron cost 0.0723463959417 after iteration 48
# Perceptron cost 0.0706318562692 after iteration 49
# Perceptron cost 0.0689173165966 after iteration 50
# Perceptron cost 0.0672027769241 after iteration 51
# Perceptron cost 0.0654882372515 after iteration 52
# Perceptron cost 0.0637736975789 after iteration 53
# Perceptron cost 0.0620591579064 after iteration 54
# Perceptron cost 0.0606068567445 after iteration 55
# Perceptron cost 0.059581258192 after iteration 56
# Perceptron cost 0.0587403946194 after iteration 57
# Perceptron cost 0.0580365080921 after iteration 58
# Perceptron cost 0.0574980519954 after iteration 59
# Perceptron cost 0.0569595958987 after iteration 60
# Perceptron cost 0.056421139802 after iteration 61
# Perceptron cost 0.0558826837054 after iteration 62
# Perceptron cost 0.0553442276087 after iteration 63
# Perceptron cost 0.054805771512 after iteration 64
# Perceptron cost 0.0542673154154 after iteration 65
# Perceptron cost 0.0537288593187 after iteration 66
# Perceptron cost 0.053190403222 after iteration 67
# Perceptron cost 0.0526519471253 after iteration 68
# Perceptron cost 0.0521134910287 after iteration 69
# Perceptron cost 0.051575034932 after iteration 70
# Perceptron cost 0.0510365788353 after iteration 71
# Perceptron cost 0.0504981227387 after iteration 72
# Perceptron cost 0.049959666642 after iteration 73
# Perceptron cost 0.0494212105453 after iteration 74
# Perceptron cost 0.0488827544487 after iteration 75
# Perceptron cost 0.048344298352 after iteration 76
# Perceptron cost 0.0478058422553 after iteration 77
# Perceptron cost 0.0472673861586 after iteration 78
# Perceptron cost 0.046728930062 after iteration 79
# Perceptron cost 0.0461904739653 after iteration 80
# Perceptron cost 0.0456520178686 after iteration 81
# Perceptron cost 0.045113561772 after iteration 82
# Perceptron cost 0.0445751056753 after iteration 83
# Perceptron cost 0.0440366495786 after iteration 84
# Perceptron cost 0.0434981934819 after iteration 85
# Perceptron cost 0.0429597373853 after iteration 86
# Perceptron cost 0.0424927758271 after iteration 87
# Perceptron cost 0.0422025139221 after iteration 88
# Perceptron cost 0.0419122520171 after iteration 89
# Perceptron cost 0.0416219901121 after iteration 90
# Perceptron cost 0.0413317282071 after iteration 91
# Perceptron cost 0.0410414663021 after iteration 92
# Perceptron cost 0.0407512043971 after iteration 93
# Perceptron cost 0.0404609424921 after iteration 94
# Perceptron cost 0.0401706805871 after iteration 95
# Perceptron cost 0.0398804186821 after iteration 96
# Perceptron cost 0.0395901567771 after iteration 97
# Perceptron cost 0.0392998948721 after iteration 98
# Perceptron cost 0.0390096329671 after iteration 99
# Perceptron cost 0.0387193710621 after iteration 100
# Perceptron cost 0.0384291091571 after iteration 101
# Perceptron cost 0.0381388472521 after iteration 102
# Perceptron cost 0.0378485853471 after iteration 103
# Perceptron cost 0.0375583234421 after iteration 104
# Perceptron cost 0.0372680615371 after iteration 105
# Perceptron cost 0.0369777996321 after iteration 106
# Perceptron cost 0.0366875377271 after iteration 107
# Perceptron cost 0.0363972758221 after iteration 108
# Perceptron cost 0.0361070139171 after iteration 109
# Perceptron cost 0.0358167520121 after iteration 110
# Perceptron cost 0.0355264901071 after iteration 111
# Perceptron cost 0.0352362282021 after iteration 112
# Perceptron cost 0.0349459662971 after iteration 113
# Perceptron cost 0.0346557043921 after iteration 114
# Perceptron cost 0.0343654424871 after iteration 115
# Perceptron cost 0.0340751805821 after iteration 116
# Perceptron cost 0.0337849186771 after iteration 117
# Perceptron cost 0.0334946567721 after iteration 118
# Perceptron cost 0.0332043948671 after iteration 119
# Perceptron cost 0.0329141329621 after iteration 120
# Perceptron cost 0.0326238710571 after iteration 121
# Perceptron cost 0.0323336091521 after iteration 122
# Perceptron cost 0.0320433472471 after iteration 123
# Perceptron cost 0.0318188346737 after iteration 124
# Perceptron cost 0.0316247418047 after iteration 125
# Perceptron cost 0.0314306489357 after iteration 126
# Perceptron cost 0.0312365560667 after iteration 127
# Perceptron cost 0.0310424631977 after iteration 128
# Perceptron cost 0.0308483703287 after iteration 129
# Perceptron cost 0.0306542774597 after iteration 130
# Perceptron cost 0.0304601845907 after iteration 131
# Perceptron cost 0.0302660917217 after iteration 132
# Perceptron cost 0.0300719988527 after iteration 133
# Perceptron cost 0.0298779059837 after iteration 134
# Perceptron cost 0.0296838131147 after iteration 135
# Perceptron cost 0.0294897202457 after iteration 136
# Perceptron cost 0.0292956273767 after iteration 137
# Perceptron cost 0.0291015345077 after iteration 138
# Perceptron cost 0.0289074416387 after iteration 139
# Perceptron cost 0.0287133487697 after iteration 140
# Perceptron cost 0.0285192559007 after iteration 141
# Perceptron cost 0.0283251630317 after iteration 142
# Perceptron cost 0.0281310701627 after iteration 143
# Perceptron cost 0.0279369772937 after iteration 144
# Perceptron cost 0.0277428844247 after iteration 145
# Perceptron cost 0.0275487915557 after iteration 146
# Perceptron cost 0.0273546986867 after iteration 147
# Perceptron cost 0.0271606058177 after iteration 148
# Perceptron cost 0.0269665129487 after iteration 149
# Perceptron cost 0.0267724200797 after iteration 150
# Perceptron cost 0.0265783272107 after iteration 151
# Perceptron cost 0.0263842343417 after iteration 152
# Perceptron cost 0.0261901414727 after iteration 153
# Perceptron cost 0.0259960486037 after iteration 154
# Perceptron cost 0.0258019557347 after iteration 155
# Perceptron cost 0.0256078628657 after iteration 156
# Perceptron cost 0.0254137699967 after iteration 157
# Perceptron cost 0.0252196771277 after iteration 158
# Perceptron cost 0.0250255842587 after iteration 159
# Perceptron cost 0.0248314913897 after iteration 160
# Perceptron cost 0.0246373985207 after iteration 161
# Perceptron cost 0.0244433056517 after iteration 162
# Perceptron cost 0.0242492127827 after iteration 163
# Perceptron cost 0.0240551199137 after iteration 164
# Perceptron cost 0.0238610270447 after iteration 165
# Perceptron cost 0.0236669341757 after iteration 166
# Perceptron cost 0.0234728413067 after iteration 167
# Perceptron cost 0.0232787484377 after iteration 168
# Perceptron cost 0.0230846555687 after iteration 169
# Perceptron cost 0.0228905626997 after iteration 170
# Perceptron cost 0.0226964698307 after iteration 171
# Perceptron cost 0.0225023769617 after iteration 172
# Perceptron cost 0.0223082840927 after iteration 173
# Perceptron cost 0.0221141912237 after iteration 174
# Perceptron cost 0.0219200983547 after iteration 175
# Perceptron cost 0.0217260054857 after iteration 176
# Perceptron cost 0.0215319126167 after iteration 177
# Perceptron cost 0.0213378197477 after iteration 178
# Perceptron cost 0.0211437268787 after iteration 179
# Perceptron cost 0.0209496340097 after iteration 180
# Perceptron cost 0.0207555411407 after iteration 181
# Perceptron cost 0.0205614482717 after iteration 182
# Perceptron cost 0.0203673554027 after iteration 183
# Perceptron cost 0.0201732625337 after iteration 184
# Perceptron cost 0.0199791696647 after iteration 185
# Perceptron cost 0.0197850767957 after iteration 186
# Perceptron cost 0.0195909839267 after iteration 187
# Perceptron cost 0.0193968910577 after iteration 188
# Perceptron cost 0.0192027981887 after iteration 189
# Perceptron cost 0.0190087053197 after iteration 190
# Perceptron cost 0.0188146124507 after iteration 191
# Perceptron cost 0.0186205195817 after iteration 192
# Perceptron cost 0.0184264267127 after iteration 193
# Perceptron cost 0.0182323338437 after iteration 194
# Perceptron cost 0.0180382409747 after iteration 195
# Perceptron cost 0.0178441481057 after iteration 196
# Perceptron cost 0.0176500552367 after iteration 197
# Perceptron cost 0.0174559623677 after iteration 198
# Perceptron cost 0.0172618694987 after iteration 199
# Perceptron cost 0.0170677766297 after iteration 200
# Perceptron cost 0.0168736837607 after iteration 201
# Perceptron cost 0.0166795908917 after iteration 202
# Perceptron cost 0.0164854980227 after iteration 203
# Perceptron cost 0.0162914051537 after iteration 204
# Perceptron cost 0.0160973122847 after iteration 205
# Perceptron cost 0.0159032194157 after iteration 206
# Perceptron cost 0.0157091265467 after iteration 207
# Perceptron cost 0.0155150336777 after iteration 208
# Perceptron cost 0.0153209408087 after iteration 209
# Perceptron cost 0.0151268479397 after iteration 210
# Perceptron cost 0.0149327550707 after iteration 211
# Perceptron cost 0.0147386622017 after iteration 212
# Perceptron cost 0.0145445693327 after iteration 213
# Perceptron cost 0.0143504764637 after iteration 214
# Perceptron cost 0.0141563835947 after iteration 215
# Perceptron cost 0.0139622907257 after iteration 216
# Perceptron cost 0.0137681978567 after iteration 217
# Perceptron cost 0.0135741049877 after iteration 218
# Perceptron cost 0.0134488959692 after iteration 219
# Perceptron cost 0.0132802264016 after iteration 220
# Perceptron cost 0.0131524221034 after iteration 221
# Perceptron cost 0.0129977618264 after iteration 222
# Perceptron cost 0.0128445342267 after iteration 223
# Perceptron cost 0.0127152972512 after iteration 224
# Perceptron cost 0.0125466276837 after iteration 225
# Perceptron cost 0.0124228513423 after iteration 226
# Perceptron cost 0.0122641631084 after iteration 227
# Perceptron cost 0.0121149634657 after iteration 228
# Perceptron cost 0.0119816985332 after iteration 229
# Perceptron cost 0.0118130289657 after iteration 230
# Perceptron cost 0.0116932805813 after iteration 231
# Perceptron cost 0.0115305643905 after iteration 232
# Perceptron cost 0.0113853927046 after iteration 233
# Perceptron cost 0.0112480998153 after iteration 234
# Perceptron cost 0.0110794302477 after iteration 235
# Perceptron cost 0.0109637098203 after iteration 236
# Perceptron cost 0.0107969656725 after iteration 237
# Perceptron cost 0.0106558219436 after iteration 238
# Perceptron cost 0.0105145010973 after iteration 239
# Perceptron cost 0.0103479340669 after iteration 240
# Perceptron cost 0.0102320365221 after iteration 241
# Perceptron cost 0.0100633669546 after iteration 242
# Perceptron cost 0.00992625118253 after iteration 243
# Perceptron cost 0.00978090237935 after iteration 244
# Perceptron cost 0.00961836330585 after iteration 245
# Perceptron cost 0.00949843780413 after iteration 246
# Perceptron cost 0.0093297682366 after iteration 247
# Perceptron cost 0.00919668042149 after iteration 248
# Perceptron cost 0.00904730366139 after iteration 249
# Perceptron cost 0.00888879254481 after iteration 250
# Perceptron cost 0.00876483908617 after iteration 251
# Perceptron cost 0.00859616951864 after iteration 252
# Perceptron cost 0.00846710966045 after iteration 253
# Perceptron cost 0.00831370494342 after iteration 254
# Perceptron cost 0.00815922178377 after iteration 255
# Perceptron cost 0.00803124036821 after iteration 256
# Perceptron cost 0.00786257080068 after iteration 257
# Perceptron cost 0.0077375388994 after iteration 258
# Perceptron cost 0.00758010622546 after iteration 259
# Perceptron cost 0.00742965102272 after iteration 260
# Perceptron cost 0.00729764165025 after iteration 261
# Perceptron cost 0.00712897208272 after iteration 262
# Perceptron cost 0.00705486153168 after iteration 263
# Perceptron cost 0.00700640444295 after iteration 264
# Perceptron cost 0.00696504286756 after iteration 265
# Perceptron cost 0.00695788482367 after iteration 266
# Perceptron cost 0.00692288982662 after iteration 267
# Perceptron cost 0.00688152825123 after iteration 268
# Perceptron cost 0.00686090811566 after iteration 269
# Perceptron cost 0.00683937521028 after iteration 270
# Perceptron cost 0.0067980136349 after iteration 271
# Perceptron cost 0.00676393140764 after iteration 272
# Perceptron cost 0.00675586059395 after iteration 273
# Perceptron cost 0.00671449901857 after iteration 274
# Perceptron cost 0.00667313744318 after iteration 275
# Perceptron cost 0.00666616323407 after iteration 276
# Perceptron cost 0.00663098440223 after iteration 277
# Perceptron cost 0.00658962282685 after iteration 278
# Perceptron cost 0.00656918652606 after iteration 279
# Perceptron cost 0.0065474697859 after iteration 280
# Perceptron cost 0.00650610821051 after iteration 281
# Perceptron cost 0.00647220981805 after iteration 282
# Perceptron cost 0.00646395516957 after iteration 283
# Perceptron cost 0.00642259359418 after iteration 284
# Perceptron cost 0.0063812320188 after iteration 285
# Perceptron cost 0.00637444164448 after iteration 286
# Perceptron cost 0.00633907897785 after iteration 287
# Perceptron cost 0.00629771740246 after iteration 288
# Perceptron cost 0.00627746493647 after iteration 289
# Perceptron cost 0.00625556436152 after iteration 290
# Perceptron cost 0.00621420278613 after iteration 291
# Perceptron cost 0.00618048822846 after iteration 292
# Perceptron cost 0.00617204974519 after iteration 293
# Perceptron cost 0.0061306881698 after iteration 294
# Perceptron cost 0.00608932659441 after iteration 295
# Perceptron cost 0.00608272005489 after iteration 296
# Perceptron cost 0.00604717355347 after iteration 297
# Perceptron cost 0.00600581197808 after iteration 298
# Perceptron cost 0.00598574334687 after iteration 299
# Perceptron cost 0.00596365893714 after iteration 300
# Perceptron cost 0.00592229736175 after iteration 301
# Perceptron cost 0.00588876663886 after iteration 302
# Perceptron cost 0.00588014432081 after iteration 303
# Perceptron cost 0.00583878274542 after iteration 304
# Perceptron cost 0.00579742117003 after iteration 305
# Perceptron cost 0.00579099846529 after iteration 306
# Perceptron cost 0.00575526812909 after iteration 307
# Perceptron cost 0.0057139065537 after iteration 308
# Perceptron cost 0.00569402175728 after iteration 309
# Perceptron cost 0.00567175351275 after iteration 310
# Perceptron cost 0.00563039193737 after iteration 311
# Perceptron cost 0.00559704504927 after iteration 312
# Perceptron cost 0.00558823889642 after iteration 313
# Perceptron cost 0.00554687732104 after iteration 314
# Perceptron cost 0.00550551574565 after iteration 315
# Perceptron cost 0.0054992768757 after iteration 316
# Perceptron cost 0.0054633627047 after iteration 317
# Perceptron cost 0.00542200112932 after iteration 318
# Perceptron cost 0.00540230016769 after iteration 319
# Perceptron cost 0.00537984808837 after iteration 320
# Perceptron cost 0.00533848651298 after iteration 321
# Perceptron cost 0.00530532345967 after iteration 322
# Perceptron cost 0.00529633347204 after iteration 323
# Perceptron cost 0.00525497189665 after iteration 324
# Perceptron cost 0.00521361032127 after iteration 325
# Perceptron cost 0.0052075552861 after iteration 326
# Perceptron cost 0.00517145728032 after iteration 327
# Perceptron cost 0.00513009570493 after iteration 328
# Perceptron cost 0.00511057857809 after iteration 329
# Perceptron cost 0.00508794266399 after iteration 330
# Perceptron cost 0.0050465810886 after iteration 331
# Perceptron cost 0.00501360187008 after iteration 332
# Perceptron cost 0.00500442804766 after iteration 333
# Perceptron cost 0.00496306647227 after iteration 334
# Perceptron cost 0.00492170489688 after iteration 335
# Perceptron cost 0.00491583369651 after iteration 336
# Perceptron cost 0.00487955185594 after iteration 337
# Perceptron cost 0.00483819028055 after iteration 338
# Perceptron cost 0.0048188569885 after iteration 339
# Perceptron cost 0.00479603723961 after iteration 340
# Perceptron cost 0.00475467566422 after iteration 341
# Perceptron cost 0.00472188028048 after iteration 342
# Perceptron cost 0.00471252262328 after iteration 343
# Perceptron cost 0.00467116104789 after iteration 344
# Perceptron cost 0.0046297994725 after iteration 345
# Perceptron cost 0.00462411210691 after iteration 346
# Perceptron cost 0.00458764643156 after iteration 347
# Perceptron cost 0.00454628485617 after iteration 348
# Perceptron cost 0.0045271353989 after iteration 349
# Perceptron cost 0.00450413181522 after iteration 350
# Perceptron cost 0.00446277023984 after iteration 351
# Perceptron cost 0.00443015869089 after iteration 352
# Perceptron cost 0.00442061719889 after iteration 353
# Perceptron cost 0.00437925562351 after iteration 354
# Perceptron cost 0.00433789404812 after iteration 355
# Perceptron cost 0.00433239051732 after iteration 356
# Perceptron cost 0.00429574100717 after iteration 357
# Perceptron cost 0.00425437943179 after iteration 358
# Perceptron cost 0.00423541380931 after iteration 359
# Perceptron cost 0.00421222639084 after iteration 360
# Perceptron cost 0.00417086481546 after iteration 361
# Perceptron cost 0.0041384371013 after iteration 362
# Perceptron cost 0.00412871177451 after iteration 363
# Perceptron cost 0.00408735019912 after iteration 364
# Perceptron cost 0.00404598862374 after iteration 365
# Perceptron cost 0.00404066892773 after iteration 366
# Perceptron cost 0.00400383558279 after iteration 367
# Perceptron cost 0.0039624740074 after iteration 368
# Perceptron cost 0.00394369221971 after iteration 369
# Perceptron cost 0.00392032096646 after iteration 370
# Perceptron cost 0.00387895939107 after iteration 371
# Perceptron cost 0.0038467155117 after iteration 372
# Perceptron cost 0.00383680635013 after iteration 373
# Perceptron cost 0.00379544477474 after iteration 374
# Perceptron cost 0.00375408319935 after iteration 375
# Perceptron cost 0.00374894733813 after iteration 376
# Perceptron cost 0.00371193015841 after iteration 377
# Perceptron cost 0.00367056858302 after iteration 378
# Perceptron cost 0.00365197063012 after iteration 379
# Perceptron cost 0.00362841554208 after iteration 380
# Perceptron cost 0.00358705396669 after iteration 381
# Perceptron cost 0.00355499392211 after iteration 382
# Perceptron cost 0.00354490092575 after iteration 383
# Perceptron cost 0.00350353935036 after iteration 384
# Perceptron cost 0.00346217777497 after iteration 385
# Perceptron cost 0.00345722574854 after iteration 386
# Perceptron cost 0.00342002473403 after iteration 387
# Perceptron cost 0.00337866315864 after iteration 388
# Perceptron cost 0.00336024904053 after iteration 389
# Perceptron cost 0.0033365101177 after iteration 390
# Perceptron cost 0.00329514854231 after iteration 391
# Perceptron cost 0.00326327233251 after iteration 392
# Perceptron cost 0.00325299550136 after iteration 393
# Perceptron cost 0.00321163392598 after iteration 394
# Perceptron cost 0.00317027235059 after iteration 395
# Perceptron cost 0.00316550415894 after iteration 396
# Perceptron cost 0.00312811930964 after iteration 397
# Perceptron cost 0.00308675773426 after iteration 398
# Perceptron cost 0.00306852745093 after iteration 399
# Perceptron cost 0.00304460469331 after iteration 400
# Perceptron cost 0.00300324311793 after iteration 401
# Perceptron cost 0.00297155074292 after iteration 402
# Perceptron cost 0.00296109007698 after iteration 403
# Perceptron cost 0.00291972850159 after iteration 404
# Perceptron cost 0.00287836692621 after iteration 405
# Perceptron cost 0.00287378256935 after iteration 406
# Perceptron cost 0.00283621388526 after iteration 407
# Perceptron cost 0.00279485230987 after iteration 408
# Perceptron cost 0.00277680586134 after iteration 409
# Perceptron cost 0.00275269926893 after iteration 410
# Perceptron cost 0.00271133769354 after iteration 411
# Perceptron cost 0.00267982915332 after iteration 412
# Perceptron cost 0.0026691846526 after iteration 413
# Perceptron cost 0.00262782307721 after iteration 414
# Perceptron cost 0.00258646150182 after iteration 415
# Perceptron cost 0.00258206097975 after iteration 416
# Perceptron cost 0.00254430846088 after iteration 417
# Perceptron cost 0.00250294688549 after iteration 418
# Perceptron cost 0.00248508427174 after iteration 419
# Perceptron cost 0.00246079384455 after iteration 420
# Perceptron cost 0.00241943226916 after iteration 421
# Perceptron cost 0.00238810756373 after iteration 422
# Perceptron cost 0.00237727922822 after iteration 423
# Perceptron cost 0.00233591765283 after iteration 424
# Perceptron cost 0.00229455607744 after iteration 425
# Perceptron cost 0.00229033939016 after iteration 426
# Perceptron cost 0.0022524030365 after iteration 427
# Perceptron cost 0.00221104146111 after iteration 428
# Perceptron cost 0.00219336268215 after iteration 429
# Perceptron cost 0.00216888842017 after iteration 430
# Perceptron cost 0.00212752684478 after iteration 431
# Perceptron cost 0.00209638597414 after iteration 432
# Perceptron cost 0.00208537380383 after iteration 433
# Perceptron cost 0.00204401222845 after iteration 434
# Perceptron cost 0.00200265065306 after iteration 435
# Perceptron cost 0.00199861780057 after iteration 436
# Perceptron cost 0.00196049761211 after iteration 437
# Perceptron cost 0.00191913603673 after iteration 438
# Perceptron cost 0.00190164109255 after iteration 439
# Perceptron cost 0.00187698299578 after iteration 440
# Perceptron cost 0.0018356214204 after iteration 441
# Perceptron cost 0.00180466438454 after iteration 442
# Perceptron cost 0.00179346837945 after iteration 443
# Perceptron cost 0.00175210680406 after iteration 444
# Perceptron cost 0.00171074522868 after iteration 445
# Perceptron cost 0.00170689621097 after iteration 446
# Perceptron cost 0.00166859218773 after iteration 447
# Perceptron cost 0.00162723061235 after iteration 448
# Perceptron cost 0.00160991950296 after iteration 449
# Perceptron cost 0.0015850775714 after iteration 450
# Perceptron cost 0.00154371599601 after iteration 451
# Perceptron cost 0.00151294279495 after iteration 452
# Perceptron cost 0.00150156295507 after iteration 453
# Perceptron cost 0.00146020137968 after iteration 454
# Perceptron cost 0.00141883980429 after iteration 455
# Perceptron cost 0.00141517462138 after iteration 456
# Perceptron cost 0.00137668676335 after iteration 457
# Perceptron cost 0.00133532518796 after iteration 458
# Perceptron cost 0.00131819791336 after iteration 459
# Perceptron cost 0.00129317214702 after iteration 460
# Perceptron cost 0.00125181057163 after iteration 461
# Perceptron cost 0.00122122120535 after iteration 462
# Perceptron cost 0.00120965753069 after iteration 463
# Perceptron cost 0.0011682959553 after iteration 464
# Perceptron cost 0.00112693437991 after iteration 465
# Perceptron cost 0.00112345303178 after iteration 466
# Perceptron cost 0.00108478133897 after iteration 467
# Perceptron cost 0.00104341976358 after iteration 468
# Perceptron cost 0.00102647632377 after iteration 469
# Perceptron cost 0.00100126672264 after iteration 470
# Perceptron cost 0.000959905147249 after iteration 471
# Perceptron cost 0.000929499615758 after iteration 472
# Perceptron cost 0.000917752106304 after iteration 473
# Perceptron cost 0.000876390530917 after iteration 474
# Perceptron cost 0.00083502895553 after iteration 475
# Perceptron cost 0.000831731442189 after iteration 476
# Perceptron cost 0.000792875914585 after iteration 477
# Perceptron cost 0.000751514339198 after iteration 478
# Perceptron cost 0.000734754734176 after iteration 479
# Perceptron cost 0.000709361298253 after iteration 480
# Perceptron cost 0.000667999722866 after iteration 481
# Perceptron cost 0.000637778026164 after iteration 482
# Perceptron cost 0.000625846681922 after iteration 483
# Perceptron cost 0.000584485106534 after iteration 484
# Perceptron cost 0.000543123531147 after iteration 485
# Perceptron cost 0.000540009852594 after iteration 486
# Perceptron cost 0.000500970490203 after iteration 487
# Perceptron cost 0.000459608914815 after iteration 488
# Perceptron cost 0.000443033144582 after iteration 489
# Perceptron cost 0.000417455873871 after iteration 490
# Perceptron cost 0.000376094298484 after iteration 491
# Perceptron cost 0.00034605643657 after iteration 492
# Perceptron cost 0.000333941257539 after iteration 493
# Perceptron cost 0.000292579682152 after iteration 494
# Perceptron cost 0.000251218106765 after iteration 495
# Perceptron cost 0.000248288263 after iteration 496
# Perceptron cost 0.00020906506582 after iteration 497
# Perceptron cost 0.000167703490433 after iteration 498
# Perceptron cost 0.000151311554988 after iteration 499
# Perceptron cost 0.000125550449489 after iteration 500
# Perceptron cost 8.41888741013e-05 after iteration 501
# Perceptron cost 5.43348469753e-05 after iteration 502
# Perceptron cost 4.20358331568e-05 after iteration 503
# Perceptron cost 6.74257769584e-07 after iteration 504
# Perceptron cost 0.0 after iteration 505
# Converged

# %%
# visualize data 
def vis_data(x, y, c='r'):
    plot.hold('on')
    for x_, y_ in zip(x, y):
        plot.plot(x_[0], x_[1], c+'o' if y_ == 0 else c+'+')
    plot.hold('off')
    plot.grid('on')

# %%
def vis_hyperplane(w, typ='k--'):
    plot.hold('on')

    lim0 = plot.gca().get_xlim()
    lim1 = plot.gca().get_ylim()
    m0, m1 = lim0[0], lim0[1]

    intercept0 = -(w[0] * m0 + w[-1])/w[1]
    intercept1 = -(w[0] * m1 + w[-1])/w[1]
    
    plt1, = plot.plot([m0, m1], [intercept0, intercept1], typ)

    plot.gca().set_xlim(lim0)
    plot.gca().set_ylim(lim1)
    
    plot.hold('off')
    
    return plt1

# %%
plot.figure()

vis_data(x_tra, y_tra, c='r')
#vis_data(x_tes, y_tes, c='b')

plt0 = vis_hyperplane(w0, 'k-.')
plt1 = vis_hyperplane(w, 'k--')
plot.legend([plt0, plt1], [
        'Initial: ${:.2} x_1 + {:.2} x_2 + {:.2} = 0$'.format(*list(w0)),
        'Final: ${:.2} x_1 + {:.2} x_2 + {:.2} = 0$'.format(*list(w))],
           loc='best')

plot.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
tra_er = numpy.sum(numpy.abs(perceptron(x_tra, w) - y_tra)) / numpy.float(len(y_tra))
tes_er = numpy.sum(numpy.abs(perceptron(x_tes, w) - y_tes)) / numpy.float(len(y_tes))

print 'Training error rate {}, Test error rate {}'.format(tra_er, tes_er)
# Out:
# Training error rate 0.0, Test error rate 0.06
