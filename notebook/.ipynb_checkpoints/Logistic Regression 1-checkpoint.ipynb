# %%
# %matplotlib notebook 

import numpy
import matplotlib.pyplot as plot

# %%
import matplotlib
matplotlib.rc('text', usetex=True)

# %%
numpy.random.seed(1234)

# %%
# data set generation
n_dim = 2
n_mean = numpy.array([0., -1.])
n_cov = numpy.diag([0.2, .5])
p_mean = numpy.array([1., 1.])
p_cov = numpy.diag([.5, .3])

# generate postive examples
n_pos = 50
pos_y = numpy.ones(n_pos) 
pos_x = numpy.random.randn(n_pos, n_dim) * numpy.diag(p_cov)[None, :] + p_mean[None,:]
# generate negative examples
n_neg = 50
neg_y = numpy.zeros(n_neg)
neg_x = numpy.random.randn(n_neg, n_dim) * numpy.diag(n_cov)[None, :] + n_mean[None,:]
# combine them
y = numpy.concatenate([pos_y, neg_y])
x = numpy.concatenate([pos_x, neg_x], axis=0)
# shuffle them
si = numpy.random.permutation(n_pos + n_neg)
y = y[si]
x = x[si]

# grab training examples
n_tra = numpy.round(0.5 * (n_pos + n_neg)).astype(numpy.int)

y_tra = y[:n_tra]
x_tra = x[:n_tra]

y_tes = y[n_tra:]
x_tes = x[n_tra:]

# %%
def sigmoid(a):
    return 1. / (1. + numpy.exp(-a))

# %%
def logreg(x, w, pre=False):
    x = x.reshape([1, -1]) if len(x.shape) < 2 else x
    
    y = numpy.sum(x * w[None,:-1], axis=1) + w[-1]
    if pre:
        return y    
    return sigmoid(y)

# %%
def logreg_dist(y, x, w, avg=False):
    y_ = logreg(x, w)
    
    d = -(y * numpy.log(y_) + (1. - y) * numpy.log(1-y_))
    
    if not avg:
        return d
    return numpy.mean(d)

# %%
def logreg_rule(y, x, w):
    y_ = logreg(x, w)
    dw = numpy.zeros(w.shape)
    dw[:-1] = numpy.mean((y_tra - y_)[:, None] * x, axis=0)
    dw[-1] = numpy.mean(y_tra - pred_y)
    return dw

# %%
w0 = numpy.random.randn(n_dim+1); w0[-1] = 0.
w = numpy.copy(w0)

n_iter = 1000
eta = 1.
old_cost = numpy.Inf
for ni in xrange(n_iter):
    pred_y = logreg(x_tra, w)
    w += eta * logreg_rule(y_tra, x_tra, w)
    cost = logreg_dist(y_tra, x_tra, w, avg=True)
    print 'Logistic regression cost {} after iteration {}'.format(cost, ni)
    if cost < 1e-16 or cost / old_cost >= 1.:
        print 'Converged'
        break
    old_cost = cost
# Out:
# Logistic regression cost 0.40432794924 after iteration 0
# Logistic regression cost 0.308908516267 after iteration 1
# Logistic regression cost 0.254114756352 after iteration 2
# Logistic regression cost 0.21830331364 after iteration 3
# Logistic regression cost 0.192827935338 after iteration 4
# Logistic regression cost 0.173633553935 after iteration 5
# Logistic regression cost 0.158565046306 after iteration 6
# Logistic regression cost 0.146366252499 after iteration 7
# Logistic regression cost 0.136252330975 after iteration 8
# Logistic regression cost 0.127705838604 after iteration 9
# Logistic regression cost 0.120370737589 after iteration 10
# Logistic regression cost 0.113993388636 after iteration 11
# Logistic regression cost 0.108387820994 after iteration 12
# Logistic regression cost 0.103414329634 after iteration 13
# Logistic regression cost 0.098965766753 after iteration 14
# Logistic regression cost 0.0949584685511 after iteration 15
# Logistic regression cost 0.0913260777899 after iteration 16
# Logistic regression cost 0.0880152331711 after iteration 17
# Logistic regression cost 0.0849824956768 after iteration 18
# Logistic regression cost 0.08219211457 after iteration 19
# Logistic regression cost 0.0796143757233 after iteration 20
# Logistic regression cost 0.0772243616279 after iteration 21
# Logistic regression cost 0.0750010075033 after iteration 22
# Logistic regression cost 0.0729263737256 after iteration 23
# Logistic regression cost 0.0709850785437 after iteration 24
# Logistic regression cost 0.0691638511132 after iteration 25
# Logistic regression cost 0.0674511759211 after iteration 26
# Logistic regression cost 0.0658370073931 after iteration 27
# Logistic regression cost 0.0643125389397 after iteration 28
# Logistic regression cost 0.0628700146283 after iteration 29
# Logistic regression cost 0.0615025745192 after iteration 30
# Logistic regression cost 0.0602041268049 after iteration 31
# Logistic regression cost 0.0589692414524 after iteration 32
# Logistic regression cost 0.0577930612161 after iteration 33
# Logistic regression cost 0.0566712267792 after iteration 34
# Logistic regression cost 0.0555998134552 after iteration 35
# Logistic regression cost 0.0545752774065 after iteration 36
# Logistic regression cost 0.0535944097397 after iteration 37
# Logistic regression cost 0.052654297154 after iteration 38
# Logistic regression cost 0.05175228807 after iteration 39
# Logistic regression cost 0.0508859633622 after iteration 40
# Logistic regression cost 0.0500531109755 after iteration 41
# Logistic regression cost 0.0492517038339 after iteration 42
# Logistic regression cost 0.0484798805495 after iteration 43
# Logistic regression cost 0.0477359285237 after iteration 44
# Logistic regression cost 0.0470182690986 after iteration 45
# Logistic regression cost 0.0463254444723 after iteration 46
# Logistic regression cost 0.045656106136 after iteration 47
# Logistic regression cost 0.0450090046295 after iteration 48
# Logistic regression cost 0.0443829804409 after iteration 49
# Logistic regression cost 0.0437769559037 after iteration 50
# Logistic regression cost 0.0431899279643 after iteration 51
# Logistic regression cost 0.0426209617124 after iteration 52
# Logistic regression cost 0.0420691845813 after iteration 53
# Logistic regression cost 0.0415337811372 after iteration 54
# Logistic regression cost 0.0410139883899 after iteration 55
# Logistic regression cost 0.0405090915622 after iteration 56
# Logistic regression cost 0.0400184202683 after iteration 57
# Logistic regression cost 0.039541345054 after iteration 58
# Logistic regression cost 0.0390772742596 after iteration 59
# Logistic regression cost 0.038625651171 after iteration 60
# Logistic regression cost 0.0381859514266 after iteration 61
# Logistic regression cost 0.0377576806564 after iteration 62
# Logistic regression cost 0.0373403723256 after iteration 63
# Logistic regression cost 0.0369335857653 after iteration 64
# Logistic regression cost 0.0365369043697 after iteration 65
# Logistic regression cost 0.0361499339436 after iteration 66
# Logistic regression cost 0.0357723011864 after iteration 67
# Logistic regression cost 0.035403652299 after iteration 68
# Logistic regression cost 0.0350436517016 after iteration 69
# Logistic regression cost 0.0346919808536 after iteration 70
# Logistic regression cost 0.0343483371643 after iteration 71
# Logistic regression cost 0.0340124329877 after iteration 72
# Logistic regression cost 0.0336839946929 after iteration 73
# Logistic regression cost 0.0333627618046 after iteration 74
# Logistic regression cost 0.0330484862064 after iteration 75
# Logistic regression cost 0.0327409314019 after iteration 76
# Logistic regression cost 0.0324398718295 after iteration 77
# Logistic regression cost 0.0321450922249 after iteration 78
# Logistic regression cost 0.0318563870292 after iteration 79
# Logistic regression cost 0.0315735598372 after iteration 80
# Logistic regression cost 0.0312964228835 after iteration 81
# Logistic regression cost 0.0310247965635 after iteration 82
# Logistic regression cost 0.0307585089862 after iteration 83
# Logistic regression cost 0.0304973955567 after iteration 84
# Logistic regression cost 0.0302412985852 after iteration 85
# Logistic regression cost 0.0299900669221 after iteration 86
# Logistic regression cost 0.0297435556157 after iteration 87
# Logistic regression cost 0.0295016255916 after iteration 88
# Logistic regression cost 0.0292641433521 after iteration 89
# Logistic regression cost 0.0290309806941 after iteration 90
# Logistic regression cost 0.0288020144442 after iteration 91
# Logistic regression cost 0.0285771262096 after iteration 92
# Logistic regression cost 0.0283562021439 after iteration 93
# Logistic regression cost 0.0281391327269 after iteration 94
# Logistic regression cost 0.0279258125572 after iteration 95
# Logistic regression cost 0.0277161401565 after iteration 96
# Logistic regression cost 0.0275100177853 after iteration 97
# Logistic regression cost 0.027307351269 after iteration 98
# Logistic regression cost 0.0271080498339 after iteration 99
# Logistic regression cost 0.0269120259521 after iteration 100
# Logistic regression cost 0.0267191951946 after iteration 101
# Logistic regression cost 0.0265294760935 after iteration 102
# Logistic regression cost 0.0263427900099 after iteration 103
# Logistic regression cost 0.0261590610109 after iteration 104
# Logistic regression cost 0.0259782157511 after iteration 105
# Logistic regression cost 0.0258001833617 after iteration 106
# Logistic regression cost 0.025624895345 after iteration 107
# Logistic regression cost 0.0254522854736 after iteration 108
# Logistic regression cost 0.0252822896962 after iteration 109
# Logistic regression cost 0.0251148460466 after iteration 110
# Logistic regression cost 0.0249498945581 after iteration 111
# Logistic regression cost 0.0247873771822 after iteration 112
# Logistic regression cost 0.0246272377111 after iteration 113
# Logistic regression cost 0.0244694217036 after iteration 114
# Logistic regression cost 0.0243138764153 after iteration 115
# Logistic regression cost 0.0241605507317 after iteration 116
# Logistic regression cost 0.0240093951043 after iteration 117
# Logistic regression cost 0.0238603614906 after iteration 118
# Logistic regression cost 0.0237134032955 after iteration 119
# Logistic regression cost 0.0235684753168 after iteration 120
# Logistic regression cost 0.0234255336922 after iteration 121
# Logistic regression cost 0.0232845358494 after iteration 122
# Logistic regression cost 0.0231454404579 after iteration 123
# Logistic regression cost 0.0230082073834 after iteration 124
# Logistic regression cost 0.022872797644 after iteration 125
# Logistic regression cost 0.0227391733683 after iteration 126
# Logistic regression cost 0.0226072977557 after iteration 127
# Logistic regression cost 0.0224771350377 after iteration 128
# Logistic regression cost 0.0223486504416 after iteration 129
# Logistic regression cost 0.0222218101555 after iteration 130
# Logistic regression cost 0.0220965812946 after iteration 131
# Logistic regression cost 0.0219729318691 after iteration 132
# Logistic regression cost 0.0218508307535 after iteration 133
# Logistic regression cost 0.021730247657 after iteration 134
# Logistic regression cost 0.0216111530952 after iteration 135
# Logistic regression cost 0.021493518363 after iteration 136
# Logistic regression cost 0.0213773155087 after iteration 137
# Logistic regression cost 0.0212625173086 after iteration 138
# Logistic regression cost 0.0211490972435 after iteration 139
# Logistic regression cost 0.0210370294755 after iteration 140
# Logistic regression cost 0.0209262888256 after iteration 141
# Logistic regression cost 0.0208168507529 after iteration 142
# Logistic regression cost 0.0207086913338 after iteration 143
# Logistic regression cost 0.0206017872428 after iteration 144
# Logistic regression cost 0.0204961157329 after iteration 145
# Logistic regression cost 0.0203916546182 after iteration 146
# Logistic regression cost 0.0202883822561 after iteration 147
# Logistic regression cost 0.0201862775301 after iteration 148
# Logistic regression cost 0.0200853198345 after iteration 149
# Logistic regression cost 0.019985489058 after iteration 150
# Logistic regression cost 0.0198867655689 after iteration 151
# Logistic regression cost 0.0197891302011 after iteration 152
# Logistic regression cost 0.0196925642393 after iteration 153
# Logistic regression cost 0.0195970494065 after iteration 154
# Logistic regression cost 0.0195025678502 after iteration 155
# Logistic regression cost 0.0194091021307 after iteration 156
# Logistic regression cost 0.0193166352084 after iteration 157
# Logistic regression cost 0.0192251504326 after iteration 158
# Logistic regression cost 0.01913463153 after iteration 159
# Logistic regression cost 0.0190450625941 after iteration 160
# Logistic regression cost 0.0189564280747 after iteration 161
# Logistic regression cost 0.0188687127678 after iteration 162
# Logistic regression cost 0.0187819018057 after iteration 163
# Logistic regression cost 0.0186959806479 after iteration 164
# Logistic regression cost 0.0186109350718 after iteration 165
# Logistic regression cost 0.0185267511637 after iteration 166
# Logistic regression cost 0.018443415311 after iteration 167
# Logistic regression cost 0.0183609141931 after iteration 168
# Logistic regression cost 0.0182792347743 after iteration 169
# Logistic regression cost 0.0181983642954 after iteration 170
# Logistic regression cost 0.0181182902667 after iteration 171
# Logistic regression cost 0.0180390004608 after iteration 172
# Logistic regression cost 0.0179604829053 after iteration 173
# Logistic regression cost 0.0178827258765 after iteration 174
# Logistic regression cost 0.0178057178926 after iteration 175
# Logistic regression cost 0.0177294477076 after iteration 176
# Logistic regression cost 0.0176539043048 after iteration 177
# Logistic regression cost 0.0175790768914 after iteration 178
# Logistic regression cost 0.0175049548923 after iteration 179
# Logistic regression cost 0.0174315279449 after iteration 180
# Logistic regression cost 0.0173587858933 after iteration 181
# Logistic regression cost 0.0172867187836 after iteration 182
# Logistic regression cost 0.0172153168583 after iteration 183
# Logistic regression cost 0.0171445705518 after iteration 184
# Logistic regression cost 0.0170744704856 after iteration 185
# Logistic regression cost 0.0170050074632 after iteration 186
# Logistic regression cost 0.0169361724662 after iteration 187
# Logistic regression cost 0.0168679566498 after iteration 188
# Logistic regression cost 0.0168003513384 after iteration 189
# Logistic regression cost 0.0167333480215 after iteration 190
# Logistic regression cost 0.0166669383502 after iteration 191
# Logistic regression cost 0.0166011141325 after iteration 192
# Logistic regression cost 0.0165358673305 after iteration 193
# Logistic regression cost 0.0164711900558 after iteration 194
# Logistic regression cost 0.0164070745668 after iteration 195
# Logistic regression cost 0.0163435132648 after iteration 196
# Logistic regression cost 0.0162804986908 after iteration 197
# Logistic regression cost 0.0162180235222 after iteration 198
# Logistic regression cost 0.0161560805696 after iteration 199
# Logistic regression cost 0.0160946627738 after iteration 200
# Logistic regression cost 0.0160337632031 after iteration 201
# Logistic regression cost 0.0159733750498 after iteration 202
# Logistic regression cost 0.0159134916278 after iteration 203
# Logistic regression cost 0.0158541063698 after iteration 204
# Logistic regression cost 0.0157952128247 after iteration 205
# Logistic regression cost 0.0157368046547 after iteration 206
# Logistic regression cost 0.0156788756331 after iteration 207
# Logistic regression cost 0.0156214196418 after iteration 208
# Logistic regression cost 0.0155644306686 after iteration 209
# Logistic regression cost 0.0155079028054 after iteration 210
# Logistic regression cost 0.0154518302454 after iteration 211
# Logistic regression cost 0.0153962072813 after iteration 212
# Logistic regression cost 0.0153410283028 after iteration 213
# Logistic regression cost 0.015286287795 after iteration 214
# Logistic regression cost 0.0152319803358 after iteration 215
# Logistic regression cost 0.0151781005943 after iteration 216
# Logistic regression cost 0.0151246433287 after iteration 217
# Logistic regression cost 0.0150716033844 after iteration 218
# Logistic regression cost 0.0150189756923 after iteration 219
# Logistic regression cost 0.014966755267 after iteration 220
# Logistic regression cost 0.0149149372048 after iteration 221
# Logistic regression cost 0.0148635166824 after iteration 222
# Logistic regression cost 0.0148124889549 after iteration 223
# Logistic regression cost 0.0147618493543 after iteration 224
# Logistic regression cost 0.0147115932881 after iteration 225
# Logistic regression cost 0.0146617162374 after iteration 226
# Logistic regression cost 0.0146122137558 after iteration 227
# Logistic regression cost 0.0145630814677 after iteration 228
# Logistic regression cost 0.0145143150666 after iteration 229
# Logistic regression cost 0.0144659103146 after iteration 230
# Logistic regression cost 0.01441786304 after iteration 231
# Logistic regression cost 0.0143701691367 after iteration 232
# Logistic regression cost 0.0143228245624 after iteration 233
# Logistic regression cost 0.0142758253379 after iteration 234
# Logistic regression cost 0.0142291675454 after iteration 235
# Logistic regression cost 0.0141828473273 after iteration 236
# Logistic regression cost 0.0141368608855 after iteration 237
# Logistic regression cost 0.0140912044796 after iteration 238
# Logistic regression cost 0.0140458744264 after iteration 239
# Logistic regression cost 0.0140008670984 after iteration 240
# Logistic regression cost 0.0139561789227 after iteration 241
# Logistic regression cost 0.0139118063803 after iteration 242
# Logistic regression cost 0.0138677460048 after iteration 243
# Logistic regression cost 0.0138239943816 after iteration 244
# Logistic regression cost 0.0137805481466 after iteration 245
# Logistic regression cost 0.0137374039856 after iteration 246
# Logistic regression cost 0.0136945586332 after iteration 247
# Logistic regression cost 0.013652008872 after iteration 248
# Logistic regression cost 0.0136097515315 after iteration 249
# Logistic regression cost 0.0135677834875 after iteration 250
# Logistic regression cost 0.0135261016609 after iteration 251
# Logistic regression cost 0.0134847030174 after iteration 252
# Logistic regression cost 0.013443584566 after iteration 253
# Logistic regression cost 0.013402743359 after iteration 254
# Logistic regression cost 0.0133621764905 after iteration 255
# Logistic regression cost 0.013321881096 after iteration 256
# Logistic regression cost 0.0132818543516 after iteration 257
# Logistic regression cost 0.0132420934734 after iteration 258
# Logistic regression cost 0.0132025957165 after iteration 259
# Logistic regression cost 0.0131633583745 after iteration 260
# Logistic regression cost 0.0131243787788 after iteration 261
# Logistic regression cost 0.013085654298 after iteration 262
# Logistic regression cost 0.013047182337 after iteration 263
# Logistic regression cost 0.0130089603368 after iteration 264
# Logistic regression cost 0.0129709857732 after iteration 265
# Logistic regression cost 0.012933256157 after iteration 266
# Logistic regression cost 0.0128957690326 after iteration 267
# Logistic regression cost 0.0128585219782 after iteration 268
# Logistic regression cost 0.0128215126046 after iteration 269
# Logistic regression cost 0.0127847385549 after iteration 270
# Logistic regression cost 0.0127481975039 after iteration 271
# Logistic regression cost 0.0127118871576 after iteration 272
# Logistic regression cost 0.0126758052527 after iteration 273
# Logistic regression cost 0.012639949556 after iteration 274
# Logistic regression cost 0.0126043178639 after iteration 275
# Logistic regression cost 0.012568908002 after iteration 276
# Logistic regression cost 0.0125337178245 after iteration 277
# Logistic regression cost 0.0124987452136 after iteration 278
# Logistic regression cost 0.0124639880796 after iteration 279
# Logistic regression cost 0.0124294443597 after iteration 280
# Logistic regression cost 0.012395112018 after iteration 281
# Logistic regression cost 0.0123609890449 after iteration 282
# Logistic regression cost 0.0123270734569 after iteration 283
# Logistic regression cost 0.0122933632959 after iteration 284
# Logistic regression cost 0.0122598566287 after iteration 285
# Logistic regression cost 0.0122265515471 after iteration 286
# Logistic regression cost 0.012193446167 after iteration 287
# Logistic regression cost 0.0121605386282 after iteration 288
# Logistic regression cost 0.012127827094 after iteration 289
# Logistic regression cost 0.012095309751 after iteration 290
# Logistic regression cost 0.0120629848084 after iteration 291
# Logistic regression cost 0.0120308504978 after iteration 292
# Logistic regression cost 0.0119989050728 after iteration 293
# Logistic regression cost 0.011967146809 after iteration 294
# Logistic regression cost 0.0119355740031 after iteration 295
# Logistic regression cost 0.0119041849729 after iteration 296
# Logistic regression cost 0.0118729780568 after iteration 297
# Logistic regression cost 0.0118419516138 after iteration 298
# Logistic regression cost 0.0118111040228 after iteration 299
# Logistic regression cost 0.0117804336825 after iteration 300
# Logistic regression cost 0.011749939011 after iteration 301
# Logistic regression cost 0.0117196184456 after iteration 302
# Logistic regression cost 0.0116894704425 after iteration 303
# Logistic regression cost 0.0116594934765 after iteration 304
# Logistic regression cost 0.0116296860404 after iteration 305
# Logistic regression cost 0.0116000466455 after iteration 306
# Logistic regression cost 0.0115705738204 after iteration 307
# Logistic regression cost 0.0115412661114 after iteration 308
# Logistic regression cost 0.0115121220819 after iteration 309
# Logistic regression cost 0.0114831403123 after iteration 310
# Logistic regression cost 0.0114543193999 after iteration 311
# Logistic regression cost 0.011425657958 after iteration 312
# Logistic regression cost 0.0113971546166 after iteration 313
# Logistic regression cost 0.0113688080214 after iteration 314
# Logistic regression cost 0.0113406168337 after iteration 315
# Logistic regression cost 0.0113125797307 after iteration 316
# Logistic regression cost 0.0112846954046 after iteration 317
# Logistic regression cost 0.0112569625627 after iteration 318
# Logistic regression cost 0.0112293799271 after iteration 319
# Logistic regression cost 0.0112019462347 after iteration 320
# Logistic regression cost 0.0111746602366 after iteration 321
# Logistic regression cost 0.0111475206983 after iteration 322
# Logistic regression cost 0.011120526399 after iteration 323
# Logistic regression cost 0.011093676132 after iteration 324
# Logistic regression cost 0.0110669687041 after iteration 325
# Logistic regression cost 0.0110404029354 after iteration 326
# Logistic regression cost 0.0110139776594 after iteration 327
# Logistic regression cost 0.0109876917226 after iteration 328
# Logistic regression cost 0.0109615439841 after iteration 329
# Logistic regression cost 0.010935533316 after iteration 330
# Logistic regression cost 0.0109096586026 after iteration 331
# Logistic regression cost 0.0108839187408 after iteration 332
# Logistic regression cost 0.0108583126395 after iteration 333
# Logistic regression cost 0.0108328392194 after iteration 334
# Logistic regression cost 0.0108074974134 after iteration 335
# Logistic regression cost 0.0107822861656 after iteration 336
# Logistic regression cost 0.010757204432 after iteration 337
# Logistic regression cost 0.0107322511796 after iteration 338
# Logistic regression cost 0.0107074253867 after iteration 339
# Logistic regression cost 0.0106827260428 after iteration 340
# Logistic regression cost 0.0106581521478 after iteration 341
# Logistic regression cost 0.0106337027128 after iteration 342
# Logistic regression cost 0.0106093767593 after iteration 343
# Logistic regression cost 0.0105851733191 after iteration 344
# Logistic regression cost 0.0105610914345 after iteration 345
# Logistic regression cost 0.0105371301579 after iteration 346
# Logistic regression cost 0.0105132885515 after iteration 347
# Logistic regression cost 0.0104895656878 after iteration 348
# Logistic regression cost 0.0104659606486 after iteration 349
# Logistic regression cost 0.0104424725258 after iteration 350
# Logistic regression cost 0.0104191004203 after iteration 351
# Logistic regression cost 0.0103958434427 after iteration 352
# Logistic regression cost 0.0103727007128 after iteration 353
# Logistic regression cost 0.0103496713594 after iteration 354
# Logistic regression cost 0.0103267545205 after iteration 355
# Logistic regression cost 0.0103039493428 after iteration 356
# Logistic regression cost 0.0102812549819 after iteration 357
# Logistic regression cost 0.0102586706019 after iteration 358
# Logistic regression cost 0.0102361953758 after iteration 359
# Logistic regression cost 0.0102138284846 after iteration 360
# Logistic regression cost 0.0101915691178 after iteration 361
# Logistic regression cost 0.0101694164733 after iteration 362
# Logistic regression cost 0.0101473697569 after iteration 363
# Logistic regression cost 0.0101254281825 after iteration 364
# Logistic regression cost 0.0101035909718 after iteration 365
# Logistic regression cost 0.0100818573545 after iteration 366
# Logistic regression cost 0.0100602265679 after iteration 367
# Logistic regression cost 0.0100386978569 after iteration 368
# Logistic regression cost 0.0100172704739 after iteration 369
# Logistic regression cost 0.00999594367874 after iteration 370
# Logistic regression cost 0.00997471673871 after iteration 371
# Logistic regression cost 0.00995358892821 after iteration 372
# Logistic regression cost 0.00993255952881 after iteration 373
# Logistic regression cost 0.00991162782916 after iteration 374
# Logistic regression cost 0.00989079312486 after iteration 375
# Logistic regression cost 0.00987005471841 after iteration 376
# Logistic regression cost 0.00984941191911 after iteration 377
# Logistic regression cost 0.00982886404298 after iteration 378
# Logistic regression cost 0.00980841041266 after iteration 379
# Logistic regression cost 0.00978805035735 after iteration 380
# Logistic regression cost 0.00976778321274 after iteration 381
# Logistic regression cost 0.00974760832088 after iteration 382
# Logistic regression cost 0.00972752503017 after iteration 383
# Logistic regression cost 0.00970753269523 after iteration 384
# Logistic regression cost 0.00968763067686 after iteration 385
# Logistic regression cost 0.00966781834192 after iteration 386
# Logistic regression cost 0.00964809506333 after iteration 387
# Logistic regression cost 0.00962846021992 after iteration 388
# Logistic regression cost 0.00960891319641 after iteration 389
# Logistic regression cost 0.00958945338332 after iteration 390
# Logistic regression cost 0.0095700801769 after iteration 391
# Logistic regression cost 0.00955079297908 after iteration 392
# Logistic regression cost 0.00953159119737 after iteration 393
# Logistic regression cost 0.00951247424483 after iteration 394
# Logistic regression cost 0.00949344153998 after iteration 395
# Logistic regression cost 0.00947449250675 after iteration 396
# Logistic regression cost 0.00945562657439 after iteration 397
# Logistic regression cost 0.00943684317745 after iteration 398
# Logistic regression cost 0.00941814175568 after iteration 399
# Logistic regression cost 0.00939952175401 after iteration 400
# Logistic regression cost 0.00938098262245 after iteration 401
# Logistic regression cost 0.00936252381603 after iteration 402
# Logistic regression cost 0.00934414479477 after iteration 403
# Logistic regression cost 0.00932584502364 after iteration 404
# Logistic regression cost 0.00930762397243 after iteration 405
# Logistic regression cost 0.00928948111576 after iteration 406
# Logistic regression cost 0.009271415933 after iteration 407
# Logistic regression cost 0.00925342790822 after iteration 408
# Logistic regression cost 0.00923551653014 after iteration 409
# Logistic regression cost 0.00921768129206 after iteration 410
# Logistic regression cost 0.00919992169184 after iteration 411
# Logistic regression cost 0.00918223723181 after iteration 412
# Logistic regression cost 0.00916462741874 after iteration 413
# Logistic regression cost 0.00914709176381 after iteration 414
# Logistic regression cost 0.00912962978252 after iteration 415
# Logistic regression cost 0.00911224099465 after iteration 416
# Logistic regression cost 0.00909492492426 after iteration 417
# Logistic regression cost 0.00907768109957 after iteration 418
# Logistic regression cost 0.00906050905297 after iteration 419
# Logistic regression cost 0.00904340832094 after iteration 420
# Logistic regression cost 0.00902637844403 after iteration 421
# Logistic regression cost 0.00900941896678 after iteration 422
# Logistic regression cost 0.00899252943773 after iteration 423
# Logistic regression cost 0.00897570940932 after iteration 424
# Logistic regression cost 0.00895895843787 after iteration 425
# Logistic regression cost 0.00894227608357 after iteration 426
# Logistic regression cost 0.00892566191037 after iteration 427
# Logistic regression cost 0.008909115486 after iteration 428
# Logistic regression cost 0.00889263638189 after iteration 429
# Logistic regression cost 0.00887622417316 after iteration 430
# Logistic regression cost 0.00885987843854 after iteration 431
# Logistic regression cost 0.00884359876039 after iteration 432
# Logistic regression cost 0.0088273847246 after iteration 433
# Logistic regression cost 0.00881123592059 after iteration 434
# Logistic regression cost 0.00879515194125 after iteration 435
# Logistic regression cost 0.00877913238293 after iteration 436
# Logistic regression cost 0.00876317684538 after iteration 437
# Logistic regression cost 0.00874728493172 after iteration 438
# Logistic regression cost 0.0087314562484 after iteration 439
# Logistic regression cost 0.00871569040518 after iteration 440
# Logistic regression cost 0.00869998701507 after iteration 441
# Logistic regression cost 0.00868434569432 after iteration 442
# Logistic regression cost 0.00866876606238 after iteration 443
# Logistic regression cost 0.00865324774186 after iteration 444
# Logistic regression cost 0.00863779035848 after iteration 445
# Logistic regression cost 0.00862239354109 after iteration 446
# Logistic regression cost 0.00860705692158 after iteration 447
# Logistic regression cost 0.00859178013488 after iteration 448
# Logistic regression cost 0.00857656281892 after iteration 449
# Logistic regression cost 0.00856140461461 after iteration 450
# Logistic regression cost 0.00854630516577 after iteration 451
# Logistic regression cost 0.00853126411916 after iteration 452
# Logistic regression cost 0.0085162811244 after iteration 453
# Logistic regression cost 0.00850135583397 after iteration 454
# Logistic regression cost 0.00848648790316 after iteration 455
# Logistic regression cost 0.00847167699006 after iteration 456
# Logistic regression cost 0.00845692275551 after iteration 457
# Logistic regression cost 0.0084422248631 after iteration 458
# Logistic regression cost 0.00842758297911 after iteration 459
# Logistic regression cost 0.00841299677252 after iteration 460
# Logistic regression cost 0.00839846591494 after iteration 461
# Logistic regression cost 0.00838399008062 after iteration 462
# Logistic regression cost 0.00836956894639 after iteration 463
# Logistic regression cost 0.00835520219167 after iteration 464
# Logistic regression cost 0.00834088949843 after iteration 465
# Logistic regression cost 0.00832663055115 after iteration 466
# Logistic regression cost 0.00831242503679 after iteration 467
# Logistic regression cost 0.00829827264482 after iteration 468
# Logistic regression cost 0.00828417306713 after iteration 469
# Logistic regression cost 0.00827012599803 after iteration 470
# Logistic regression cost 0.00825613113423 after iteration 471
# Logistic regression cost 0.00824218817484 after iteration 472
# Logistic regression cost 0.00822829682128 after iteration 473
# Logistic regression cost 0.00821445677732 after iteration 474
# Logistic regression cost 0.00820066774903 after iteration 475
# Logistic regression cost 0.00818692944478 after iteration 476
# Logistic regression cost 0.00817324157516 after iteration 477
# Logistic regression cost 0.00815960385303 after iteration 478
# Logistic regression cost 0.00814601599346 after iteration 479
# Logistic regression cost 0.00813247771371 after iteration 480
# Logistic regression cost 0.0081189887332 after iteration 481
# Logistic regression cost 0.00810554877354 after iteration 482
# Logistic regression cost 0.00809215755842 after iteration 483
# Logistic regression cost 0.00807881481368 after iteration 484
# Logistic regression cost 0.00806552026723 after iteration 485
# Logistic regression cost 0.00805227364906 after iteration 486
# Logistic regression cost 0.00803907469121 after iteration 487
# Logistic regression cost 0.00802592312773 after iteration 488
# Logistic regression cost 0.00801281869472 after iteration 489
# Logistic regression cost 0.00799976113023 after iteration 490
# Logistic regression cost 0.00798675017431 after iteration 491
# Logistic regression cost 0.00797378556895 after iteration 492
# Logistic regression cost 0.00796086705809 after iteration 493
# Logistic regression cost 0.00794799438757 after iteration 494
# Logistic regression cost 0.00793516730515 after iteration 495
# Logistic regression cost 0.00792238556044 after iteration 496
# Logistic regression cost 0.00790964890495 after iteration 497
# Logistic regression cost 0.007896957092 after iteration 498
# Logistic regression cost 0.00788430987678 after iteration 499
# Logistic regression cost 0.00787170701625 after iteration 500
# Logistic regression cost 0.00785914826919 after iteration 501
# Logistic regression cost 0.00784663339614 after iteration 502
# Logistic regression cost 0.00783416215943 after iteration 503
# Logistic regression cost 0.00782173432311 after iteration 504
# Logistic regression cost 0.00780934965297 after iteration 505
# Logistic regression cost 0.00779700791649 after iteration 506
# Logistic regression cost 0.00778470888289 after iteration 507
# Logistic regression cost 0.00777245232304 after iteration 508
# Logistic regression cost 0.00776023800948 after iteration 509
# Logistic regression cost 0.0077480657164 after iteration 510
# Logistic regression cost 0.00773593521964 after iteration 511
# Logistic regression cost 0.00772384629664 after iteration 512
# Logistic regression cost 0.00771179872647 after iteration 513
# Logistic regression cost 0.00769979228976 after iteration 514
# Logistic regression cost 0.00768782676875 after iteration 515
# Logistic regression cost 0.00767590194722 after iteration 516
# Logistic regression cost 0.0076640176105 after iteration 517
# Logistic regression cost 0.00765217354547 after iteration 518
# Logistic regression cost 0.00764036954052 after iteration 519
# Logistic regression cost 0.00762860538553 after iteration 520
# Logistic regression cost 0.00761688087191 after iteration 521
# Logistic regression cost 0.00760519579252 after iteration 522
# Logistic regression cost 0.00759354994169 after iteration 523
# Logistic regression cost 0.00758194311522 after iteration 524
# Logistic regression cost 0.00757037511034 after iteration 525
# Logistic regression cost 0.00755884572571 after iteration 526
# Logistic regression cost 0.0075473547614 after iteration 527
# Logistic regression cost 0.00753590201888 after iteration 528
# Logistic regression cost 0.00752448730102 after iteration 529
# Logistic regression cost 0.00751311041207 after iteration 530
# Logistic regression cost 0.00750177115763 after iteration 531
# Logistic regression cost 0.00749046934467 after iteration 532
# Logistic regression cost 0.00747920478149 after iteration 533
# Logistic regression cost 0.00746797727772 after iteration 534
# Logistic regression cost 0.00745678664433 after iteration 535
# Logistic regression cost 0.00744563269357 after iteration 536
# Logistic regression cost 0.00743451523899 after iteration 537
# Logistic regression cost 0.00742343409543 after iteration 538
# Logistic regression cost 0.00741238907901 after iteration 539
# Logistic regression cost 0.0074013800071 after iteration 540
# Logistic regression cost 0.00739040669833 after iteration 541
# Logistic regression cost 0.00737946897256 after iteration 542
# Logistic regression cost 0.00736856665088 after iteration 543
# Logistic regression cost 0.00735769955561 after iteration 544
# Logistic regression cost 0.00734686751028 after iteration 545
# Logistic regression cost 0.0073360703396 after iteration 546
# Logistic regression cost 0.00732530786948 after iteration 547
# Logistic regression cost 0.00731457992701 after iteration 548
# Logistic regression cost 0.00730388634043 after iteration 549
# Logistic regression cost 0.00729322693917 after iteration 550
# Logistic regression cost 0.00728260155378 after iteration 551
# Logistic regression cost 0.00727201001595 after iteration 552
# Logistic regression cost 0.00726145215852 after iteration 553
# Logistic regression cost 0.00725092781542 after iteration 554
# Logistic regression cost 0.00724043682171 after iteration 555
# Logistic regression cost 0.00722997901354 after iteration 556
# Logistic regression cost 0.00721955422816 after iteration 557
# Logistic regression cost 0.0072091623039 after iteration 558
# Logistic regression cost 0.00719880308014 after iteration 559
# Logistic regression cost 0.00718847639736 after iteration 560
# Logistic regression cost 0.00717818209707 after iteration 561
# Logistic regression cost 0.00716792002184 after iteration 562
# Logistic regression cost 0.00715769001525 after iteration 563
# Logistic regression cost 0.00714749192195 after iteration 564
# Logistic regression cost 0.00713732558758 after iteration 565
# Logistic regression cost 0.0071271908588 after iteration 566
# Logistic regression cost 0.00711708758327 after iteration 567
# Logistic regression cost 0.00710701560966 after iteration 568
# Logistic regression cost 0.0070969747876 after iteration 569
# Logistic regression cost 0.00708696496773 after iteration 570
# Logistic regression cost 0.00707698600163 after iteration 571
# Logistic regression cost 0.00706703774186 after iteration 572
# Logistic regression cost 0.00705712004193 after iteration 573
# Logistic regression cost 0.00704723275631 after iteration 574
# Logistic regression cost 0.00703737574039 after iteration 575
# Logistic regression cost 0.00702754885049 after iteration 576
# Logistic regression cost 0.00701775194388 after iteration 577
# Logistic regression cost 0.00700798487872 after iteration 578
# Logistic regression cost 0.0069982475141 after iteration 579
# Logistic regression cost 0.00698853970999 after iteration 580
# Logistic regression cost 0.00697886132726 after iteration 581
# Logistic regression cost 0.00696921222768 after iteration 582
# Logistic regression cost 0.0069595922739 after iteration 583
# Logistic regression cost 0.00695000132943 after iteration 584
# Logistic regression cost 0.00694043925864 after iteration 585
# Logistic regression cost 0.00693090592679 after iteration 586
# Logistic regression cost 0.00692140119996 after iteration 587
# Logistic regression cost 0.00691192494509 after iteration 588
# Logistic regression cost 0.00690247702996 after iteration 589
# Logistic regression cost 0.00689305732318 after iteration 590
# Logistic regression cost 0.00688366569418 after iteration 591
# Logistic regression cost 0.00687430201322 after iteration 592
# Logistic regression cost 0.00686496615136 after iteration 593
# Logistic regression cost 0.00685565798048 after iteration 594
# Logistic regression cost 0.00684637737324 after iteration 595
# Logistic regression cost 0.00683712420311 after iteration 596
# Logistic regression cost 0.00682789834434 after iteration 597
# Logistic regression cost 0.00681869967196 after iteration 598
# Logistic regression cost 0.00680952806179 after iteration 599
# Logistic regression cost 0.0068003833904 after iteration 600
# Logistic regression cost 0.00679126553512 after iteration 601
# Logistic regression cost 0.00678217437406 after iteration 602
# Logistic regression cost 0.00677310978606 after iteration 603
# Logistic regression cost 0.00676407165071 after iteration 604
# Logistic regression cost 0.00675505984834 after iteration 605
# Logistic regression cost 0.00674607426002 after iteration 606
# Logistic regression cost 0.00673711476754 after iteration 607
# Logistic regression cost 0.00672818125342 after iteration 608
# Logistic regression cost 0.00671927360088 after iteration 609
# Logistic regression cost 0.00671039169387 after iteration 610
# Logistic regression cost 0.00670153541704 after iteration 611
# Logistic regression cost 0.00669270465574 after iteration 612
# Logistic regression cost 0.006683899296 after iteration 613
# Logistic regression cost 0.00667511922457 after iteration 614
# Logistic regression cost 0.00666636432885 after iteration 615
# Logistic regression cost 0.00665763449696 after iteration 616
# Logistic regression cost 0.00664892961765 after iteration 617
# Logistic regression cost 0.00664024958037 after iteration 618
# Logistic regression cost 0.00663159427522 after iteration 619
# Logistic regression cost 0.00662296359296 after iteration 620
# Logistic regression cost 0.006614357425 after iteration 621
# Logistic regression cost 0.00660577566342 after iteration 622
# Logistic regression cost 0.00659721820093 after iteration 623
# Logistic regression cost 0.00658868493086 after iteration 624
# Logistic regression cost 0.0065801757472 after iteration 625
# Logistic regression cost 0.00657169054456 after iteration 626
# Logistic regression cost 0.00656322921818 after iteration 627
# Logistic regression cost 0.00655479166392 after iteration 628
# Logistic regression cost 0.00654637777824 after iteration 629
# Logistic regression cost 0.00653798745823 after iteration 630
# Logistic regression cost 0.00652962060157 after iteration 631
# Logistic regression cost 0.00652127710657 after iteration 632
# Logistic regression cost 0.00651295687211 after iteration 633
# Logistic regression cost 0.00650465979766 after iteration 634
# Logistic regression cost 0.0064963857833 after iteration 635
# Logistic regression cost 0.00648813472968 after iteration 636
# Logistic regression cost 0.00647990653804 after iteration 637
# Logistic regression cost 0.00647170111019 after iteration 638
# Logistic regression cost 0.00646351834851 after iteration 639
# Logistic regression cost 0.00645535815594 after iteration 640
# Logistic regression cost 0.006447220436 after iteration 641
# Logistic regression cost 0.00643910509275 after iteration 642
# Logistic regression cost 0.00643101203083 after iteration 643
# Logistic regression cost 0.00642294115541 after iteration 644
# Logistic regression cost 0.00641489237221 after iteration 645
# Logistic regression cost 0.00640686558749 after iteration 646
# Logistic regression cost 0.00639886070807 after iteration 647
# Logistic regression cost 0.00639087764128 after iteration 648
# Logistic regression cost 0.00638291629499 after iteration 649
# Logistic regression cost 0.00637497657759 after iteration 650
# Logistic regression cost 0.00636705839802 after iteration 651
# Logistic regression cost 0.00635916166571 after iteration 652
# Logistic regression cost 0.00635128629062 after iteration 653
# Logistic regression cost 0.00634343218322 after iteration 654
# Logistic regression cost 0.00633559925448 after iteration 655
# Logistic regression cost 0.00632778741589 after iteration 656
# Logistic regression cost 0.00631999657943 after iteration 657
# Logistic regression cost 0.00631222665758 after iteration 658
# Logistic regression cost 0.00630447756332 after iteration 659
# Logistic regression cost 0.00629674921011 after iteration 660
# Logistic regression cost 0.00628904151191 after iteration 661
# Logistic regression cost 0.00628135438315 after iteration 662
# Logistic regression cost 0.00627368773876 after iteration 663
# Logistic regression cost 0.00626604149412 after iteration 664
# Logistic regression cost 0.00625841556511 after iteration 665
# Logistic regression cost 0.00625080986806 after iteration 666
# Logistic regression cost 0.00624322431977 after iteration 667
# Logistic regression cost 0.00623565883752 after iteration 668
# Logistic regression cost 0.00622811333903 after iteration 669
# Logistic regression cost 0.00622058774249 after iteration 670
# Logistic regression cost 0.00621308196653 after iteration 671
# Logistic regression cost 0.00620559593025 after iteration 672
# Logistic regression cost 0.00619812955319 after iteration 673
# Logistic regression cost 0.00619068275532 after iteration 674
# Logistic regression cost 0.00618325545708 after iteration 675
# Logistic regression cost 0.00617584757931 after iteration 676
# Logistic regression cost 0.00616845904332 after iteration 677
# Logistic regression cost 0.00616108977084 after iteration 678
# Logistic regression cost 0.00615373968402 after iteration 679
# Logistic regression cost 0.00614640870545 after iteration 680
# Logistic regression cost 0.00613909675814 after iteration 681
# Logistic regression cost 0.00613180376551 after iteration 682
# Logistic regression cost 0.00612452965141 after iteration 683
# Logistic regression cost 0.00611727434009 after iteration 684
# Logistic regression cost 0.00611003775624 after iteration 685
# Logistic regression cost 0.00610281982493 after iteration 686
# Logistic regression cost 0.00609562047164 after iteration 687
# Logistic regression cost 0.00608843962227 after iteration 688
# Logistic regression cost 0.0060812772031 after iteration 689
# Logistic regression cost 0.00607413314083 after iteration 690
# Logistic regression cost 0.00606700736254 after iteration 691
# Logistic regression cost 0.0060598997957 after iteration 692
# Logistic regression cost 0.00605281036818 after iteration 693
# Logistic regression cost 0.00604573900823 after iteration 694
# Logistic regression cost 0.0060386856445 after iteration 695
# Logistic regression cost 0.00603165020598 after iteration 696
# Logistic regression cost 0.0060246326221 after iteration 697
# Logistic regression cost 0.00601763282262 after iteration 698
# Logistic regression cost 0.00601065073769 after iteration 699
# Logistic regression cost 0.00600368629783 after iteration 700
# Logistic regression cost 0.00599673943393 after iteration 701
# Logistic regression cost 0.00598981007725 after iteration 702
# Logistic regression cost 0.00598289815942 after iteration 703
# Logistic regression cost 0.0059760036124 after iteration 704
# Logistic regression cost 0.00596912636856 after iteration 705
# Logistic regression cost 0.00596226636058 after iteration 706
# Logistic regression cost 0.00595542352152 after iteration 707
# Logistic regression cost 0.00594859778479 after iteration 708
# Logistic regression cost 0.00594178908415 after iteration 709
# Logistic regression cost 0.00593499735369 after iteration 710
# Logistic regression cost 0.00592822252787 after iteration 711
# Logistic regression cost 0.00592146454148 after iteration 712
# Logistic regression cost 0.00591472332966 after iteration 713
# Logistic regression cost 0.00590799882788 after iteration 714
# Logistic regression cost 0.00590129097194 after iteration 715
# Logistic regression cost 0.00589459969799 after iteration 716
# Logistic regression cost 0.0058879249425 after iteration 717
# Logistic regression cost 0.00588126664228 after iteration 718
# Logistic regression cost 0.00587462473445 after iteration 719
# Logistic regression cost 0.00586799915649 after iteration 720
# Logistic regression cost 0.00586138984616 after iteration 721
# Logistic regression cost 0.00585479674156 after iteration 722
# Logistic regression cost 0.00584821978113 after iteration 723
# Logistic regression cost 0.00584165890359 after iteration 724
# Logistic regression cost 0.00583511404801 after iteration 725
# Logistic regression cost 0.00582858515374 after iteration 726
# Logistic regression cost 0.00582207216046 after iteration 727
# Logistic regression cost 0.00581557500816 after iteration 728
# Logistic regression cost 0.00580909363713 after iteration 729
# Logistic regression cost 0.00580262798797 after iteration 730
# Logistic regression cost 0.00579617800158 after iteration 731
# Logistic regression cost 0.00578974361916 after iteration 732
# Logistic regression cost 0.00578332478221 after iteration 733
# Logistic regression cost 0.00577692143252 after iteration 734
# Logistic regression cost 0.0057705335122 after iteration 735
# Logistic regression cost 0.00576416096363 after iteration 736
# Logistic regression cost 0.00575780372948 after iteration 737
# Logistic regression cost 0.00575146175273 after iteration 738
# Logistic regression cost 0.00574513497662 after iteration 739
# Logistic regression cost 0.0057388233447 after iteration 740
# Logistic regression cost 0.0057325268008 after iteration 741
# Logistic regression cost 0.00572624528902 after iteration 742
# Logistic regression cost 0.00571997875375 after iteration 743
# Logistic regression cost 0.00571372713965 after iteration 744
# Logistic regression cost 0.00570749039168 after iteration 745
# Logistic regression cost 0.00570126845505 after iteration 746
# Logistic regression cost 0.00569506127525 after iteration 747
# Logistic regression cost 0.00568886879804 after iteration 748
# Logistic regression cost 0.00568269096947 after iteration 749
# Logistic regression cost 0.00567652773584 after iteration 750
# Logistic regression cost 0.0056703790437 after iteration 751
# Logistic regression cost 0.00566424483991 after iteration 752
# Logistic regression cost 0.00565812507155 after iteration 753
# Logistic regression cost 0.00565201968599 after iteration 754
# Logistic regression cost 0.00564592863085 after iteration 755
# Logistic regression cost 0.005639851854 after iteration 756
# Logistic regression cost 0.00563378930358 after iteration 757
# Logistic regression cost 0.00562774092798 after iteration 758
# Logistic regression cost 0.00562170667584 after iteration 759
# Logistic regression cost 0.00561568649606 after iteration 760
# Logistic regression cost 0.00560968033779 after iteration 761
# Logistic regression cost 0.00560368815043 after iteration 762
# Logistic regression cost 0.0055977098836 after iteration 763
# Logistic regression cost 0.00559174548722 after iteration 764
# Logistic regression cost 0.0055857949114 after iteration 765
# Logistic regression cost 0.00557985810653 after iteration 766
# Logistic regression cost 0.00557393502321 after iteration 767
# Logistic regression cost 0.00556802561232 after iteration 768
# Logistic regression cost 0.00556212982495 after iteration 769
# Logistic regression cost 0.00555624761242 after iteration 770
# Logistic regression cost 0.00555037892632 after iteration 771
# Logistic regression cost 0.00554452371843 after iteration 772
# Logistic regression cost 0.0055386819408 after iteration 773
# Logistic regression cost 0.0055328535457 after iteration 774
# Logistic regression cost 0.00552703848561 after iteration 775
# Logistic regression cost 0.00552123671327 after iteration 776
# Logistic regression cost 0.00551544818163 after iteration 777
# Logistic regression cost 0.00550967284386 after iteration 778
# Logistic regression cost 0.00550391065337 after iteration 779
# Logistic regression cost 0.00549816156379 after iteration 780
# Logistic regression cost 0.00549242552895 after iteration 781
# Logistic regression cost 0.00548670250293 after iteration 782
# Logistic regression cost 0.00548099244002 after iteration 783
# Logistic regression cost 0.00547529529471 after iteration 784
# Logistic regression cost 0.00546961102173 after iteration 785
# Logistic regression cost 0.00546393957601 after iteration 786
# Logistic regression cost 0.00545828091271 after iteration 787
# Logistic regression cost 0.00545263498717 after iteration 788
# Logistic regression cost 0.00544700175498 after iteration 789
# Logistic regression cost 0.00544138117192 after iteration 790
# Logistic regression cost 0.00543577319399 after iteration 791
# Logistic regression cost 0.00543017777736 after iteration 792
# Logistic regression cost 0.00542459487847 after iteration 793
# Logistic regression cost 0.0054190244539 after iteration 794
# Logistic regression cost 0.00541346646049 after iteration 795
# Logistic regression cost 0.00540792085523 after iteration 796
# Logistic regression cost 0.00540238759536 after iteration 797
# Logistic regression cost 0.00539686663829 after iteration 798
# Logistic regression cost 0.00539135794163 after iteration 799
# Logistic regression cost 0.00538586146321 after iteration 800
# Logistic regression cost 0.00538037716103 after iteration 801
# Logistic regression cost 0.00537490499329 after iteration 802
# Logistic regression cost 0.00536944491841 after iteration 803
# Logistic regression cost 0.00536399689497 after iteration 804
# Logistic regression cost 0.00535856088177 after iteration 805
# Logistic regression cost 0.00535313683777 after iteration 806
# Logistic regression cost 0.00534772472215 after iteration 807
# Logistic regression cost 0.00534232449427 after iteration 808
# Logistic regression cost 0.00533693611366 after iteration 809
# Logistic regression cost 0.00533155954005 after iteration 810
# Logistic regression cost 0.00532619473338 after iteration 811
# Logistic regression cost 0.00532084165372 after iteration 812
# Logistic regression cost 0.00531550026137 after iteration 813
# Logistic regression cost 0.00531017051679 after iteration 814
# Logistic regression cost 0.00530485238063 after iteration 815
# Logistic regression cost 0.00529954581372 after iteration 816
# Logistic regression cost 0.00529425077706 after iteration 817
# Logistic regression cost 0.00528896723184 after iteration 818
# Logistic regression cost 0.00528369513942 after iteration 819
# Logistic regression cost 0.00527843446133 after iteration 820
# Logistic regression cost 0.00527318515929 after iteration 821
# Logistic regression cost 0.00526794719518 after iteration 822
# Logistic regression cost 0.00526272053107 after iteration 823
# Logistic regression cost 0.00525750512918 after iteration 824
# Logistic regression cost 0.00525230095192 after iteration 825
# Logistic regression cost 0.00524710796186 after iteration 826
# Logistic regression cost 0.00524192612174 after iteration 827
# Logistic regression cost 0.00523675539447 after iteration 828
# Logistic regression cost 0.00523159574313 after iteration 829
# Logistic regression cost 0.00522644713096 after iteration 830
# Logistic regression cost 0.00522130952137 after iteration 831
# Logistic regression cost 0.00521618287794 after iteration 832
# Logistic regression cost 0.00521106716439 after iteration 833
# Logistic regression cost 0.00520596234463 after iteration 834
# Logistic regression cost 0.00520086838272 after iteration 835
# Logistic regression cost 0.00519578524287 after iteration 836
# Logistic regression cost 0.00519071288947 after iteration 837
# Logistic regression cost 0.00518565128707 after iteration 838
# Logistic regression cost 0.00518060040034 after iteration 839
# Logistic regression cost 0.00517556019416 after iteration 840
# Logistic regression cost 0.00517053063353 after iteration 841
# Logistic regression cost 0.00516551168361 after iteration 842
# Logistic regression cost 0.00516050330974 after iteration 843
# Logistic regression cost 0.00515550547737 after iteration 844
# Logistic regression cost 0.00515051815214 after iteration 845
# Logistic regression cost 0.00514554129983 after iteration 846
# Logistic regression cost 0.00514057488636 after iteration 847
# Logistic regression cost 0.00513561887782 after iteration 848
# Logistic regression cost 0.00513067324043 after iteration 849
# Logistic regression cost 0.00512573794057 after iteration 850
# Logistic regression cost 0.00512081294477 after iteration 851
# Logistic regression cost 0.0051158982197 after iteration 852
# Logistic regression cost 0.00511099373218 after iteration 853
# Logistic regression cost 0.00510609944917 after iteration 854
# Logistic regression cost 0.00510121533778 after iteration 855
# Logistic regression cost 0.00509634136526 after iteration 856
# Logistic regression cost 0.005091477499 after iteration 857
# Logistic regression cost 0.00508662370654 after iteration 858
# Logistic regression cost 0.00508177995557 after iteration 859
# Logistic regression cost 0.00507694621389 after iteration 860
# Logistic regression cost 0.00507212244946 after iteration 861
# Logistic regression cost 0.00506730863039 after iteration 862
# Logistic regression cost 0.00506250472491 after iteration 863
# Logistic regression cost 0.00505771070138 after iteration 864
# Logistic regression cost 0.00505292652833 after iteration 865
# Logistic regression cost 0.00504815217439 after iteration 866
# Logistic regression cost 0.00504338760834 after iteration 867
# Logistic regression cost 0.00503863279911 after iteration 868
# Logistic regression cost 0.00503388771573 after iteration 869
# Logistic regression cost 0.0050291523274 after iteration 870
# Logistic regression cost 0.00502442660342 after iteration 871
# Logistic regression cost 0.00501971051325 after iteration 872
# Logistic regression cost 0.00501500402645 after iteration 873
# Logistic regression cost 0.00501030711273 after iteration 874
# Logistic regression cost 0.00500561974194 after iteration 875
# Logistic regression cost 0.00500094188403 after iteration 876
# Logistic regression cost 0.0049962735091 after iteration 877
# Logistic regression cost 0.00499161458737 after iteration 878
# Logistic regression cost 0.00498696508919 after iteration 879
# Logistic regression cost 0.00498232498503 after iteration 880
# Logistic regression cost 0.00497769424548 after iteration 881
# Logistic regression cost 0.00497307284128 after iteration 882
# Logistic regression cost 0.00496846074327 after iteration 883
# Logistic regression cost 0.00496385792241 after iteration 884
# Logistic regression cost 0.00495926434982 after iteration 885
# Logistic regression cost 0.00495467999669 after iteration 886
# Logistic regression cost 0.00495010483436 after iteration 887
# Logistic regression cost 0.0049455388343 after iteration 888
# Logistic regression cost 0.00494098196808 after iteration 889
# Logistic regression cost 0.00493643420739 after iteration 890
# Logistic regression cost 0.00493189552407 after iteration 891
# Logistic regression cost 0.00492736589002 after iteration 892
# Logistic regression cost 0.00492284527732 after iteration 893
# Logistic regression cost 0.00491833365813 after iteration 894
# Logistic regression cost 0.00491383100473 after iteration 895
# Logistic regression cost 0.00490933728952 after iteration 896
# Logistic regression cost 0.00490485248502 after iteration 897
# Logistic regression cost 0.00490037656386 after iteration 898
# Logistic regression cost 0.00489590949879 after iteration 899
# Logistic regression cost 0.00489145126266 after iteration 900
# Logistic regression cost 0.00488700182844 after iteration 901
# Logistic regression cost 0.00488256116922 after iteration 902
# Logistic regression cost 0.00487812925818 after iteration 903
# Logistic regression cost 0.00487370606863 after iteration 904
# Logistic regression cost 0.004869291574 after iteration 905
# Logistic regression cost 0.0048648857478 after iteration 906
# Logistic regression cost 0.00486048856366 after iteration 907
# Logistic regression cost 0.00485609999534 after iteration 908
# Logistic regression cost 0.00485172001667 after iteration 909
# Logistic regression cost 0.00484734860163 after iteration 910
# Logistic regression cost 0.00484298572427 after iteration 911
# Logistic regression cost 0.00483863135877 after iteration 912
# Logistic regression cost 0.00483428547941 after iteration 913
# Logistic regression cost 0.00482994806056 after iteration 914
# Logistic regression cost 0.00482561907672 after iteration 915
# Logistic regression cost 0.00482129850247 after iteration 916
# Logistic regression cost 0.00481698631253 after iteration 917
# Logistic regression cost 0.00481268248167 after iteration 918
# Logistic regression cost 0.00480838698481 after iteration 919
# Logistic regression cost 0.00480409979694 after iteration 920
# Logistic regression cost 0.00479982089318 after iteration 921
# Logistic regression cost 0.00479555024873 after iteration 922
# Logistic regression cost 0.0047912878389 after iteration 923
# Logistic regression cost 0.00478703363909 after iteration 924
# Logistic regression cost 0.00478278762481 after iteration 925
# Logistic regression cost 0.00477854977166 after iteration 926
# Logistic regression cost 0.00477432005536 after iteration 927
# Logistic regression cost 0.00477009845169 after iteration 928
# Logistic regression cost 0.00476588493657 after iteration 929
# Logistic regression cost 0.00476167948598 after iteration 930
# Logistic regression cost 0.00475748207603 after iteration 931
# Logistic regression cost 0.00475329268289 after iteration 932
# Logistic regression cost 0.00474911128286 after iteration 933
# Logistic regression cost 0.00474493785231 after iteration 934
# Logistic regression cost 0.00474077236771 after iteration 935
# Logistic regression cost 0.00473661480565 after iteration 936
# Logistic regression cost 0.00473246514277 after iteration 937
# Logistic regression cost 0.00472832335583 after iteration 938
# Logistic regression cost 0.00472418942168 after iteration 939
# Logistic regression cost 0.00472006331727 after iteration 940
# Logistic regression cost 0.00471594501961 after iteration 941
# Logistic regression cost 0.00471183450584 after iteration 942
# Logistic regression cost 0.00470773175317 after iteration 943
# Logistic regression cost 0.0047036367389 after iteration 944
# Logistic regression cost 0.00469954944043 after iteration 945
# Logistic regression cost 0.00469546983524 after iteration 946
# Logistic regression cost 0.0046913979009 after iteration 947
# Logistic regression cost 0.00468733361507 after iteration 948
# Logistic regression cost 0.00468327695551 after iteration 949
# Logistic regression cost 0.00467922790005 after iteration 950
# Logistic regression cost 0.00467518642662 after iteration 951
# Logistic regression cost 0.00467115251322 after iteration 952
# Logistic regression cost 0.00466712613795 after iteration 953
# Logistic regression cost 0.004663107279 after iteration 954
# Logistic regression cost 0.00465909591464 after iteration 955
# Logistic regression cost 0.00465509202322 after iteration 956
# Logistic regression cost 0.00465109558317 after iteration 957
# Logistic regression cost 0.00464710657303 after iteration 958
# Logistic regression cost 0.0046431249714 after iteration 959
# Logistic regression cost 0.00463915075697 after iteration 960
# Logistic regression cost 0.00463518390851 after iteration 961
# Logistic regression cost 0.00463122440488 after iteration 962
# Logistic regression cost 0.00462727222502 after iteration 963
# Logistic regression cost 0.00462332734795 after iteration 964
# Logistic regression cost 0.00461938975277 after iteration 965
# Logistic regression cost 0.00461545941866 after iteration 966
# Logistic regression cost 0.00461153632489 after iteration 967
# Logistic regression cost 0.00460762045079 after iteration 968
# Logistic regression cost 0.0046037117758 after iteration 969
# Logistic regression cost 0.00459981027942 after iteration 970
# Logistic regression cost 0.00459591594122 after iteration 971
# Logistic regression cost 0.00459202874088 after iteration 972
# Logistic regression cost 0.00458814865812 after iteration 973
# Logistic regression cost 0.00458427567276 after iteration 974
# Logistic regression cost 0.00458040976471 after iteration 975
# Logistic regression cost 0.00457655091392 after iteration 976
# Logistic regression cost 0.00457269910046 after iteration 977
# Logistic regression cost 0.00456885430444 after iteration 978
# Logistic regression cost 0.00456501650606 after iteration 979
# Logistic regression cost 0.0045611856856 after iteration 980
# Logistic regression cost 0.00455736182342 after iteration 981
# Logistic regression cost 0.00455354489994 after iteration 982
# Logistic regression cost 0.00454973489566 after iteration 983
# Logistic regression cost 0.00454593179115 after iteration 984
# Logistic regression cost 0.00454213556708 after iteration 985
# Logistic regression cost 0.00453834620415 after iteration 986
# Logistic regression cost 0.00453456368317 after iteration 987
# Logistic regression cost 0.004530787985 after iteration 988
# Logistic regression cost 0.0045270190906 after iteration 989
# Logistic regression cost 0.00452325698096 after iteration 990
# Logistic regression cost 0.00451950163718 after iteration 991
# Logistic regression cost 0.00451575304041 after iteration 992
# Logistic regression cost 0.00451201117188 after iteration 993
# Logistic regression cost 0.00450827601289 after iteration 994
# Logistic regression cost 0.00450454754481 after iteration 995
# Logistic regression cost 0.00450082574908 after iteration 996
# Logistic regression cost 0.00449711060721 after iteration 997
# Logistic regression cost 0.00449340210077 after iteration 998
# Logistic regression cost 0.00448970021142 after iteration 999

# %%
# visualize data 
def vis_data(x, y, c='r'):
    plot.hold('on')
    for x_, y_ in zip(x, y):
        plot.plot(x_[0], x_[1], c+'o' if y_ == 0 else c+'+')
    plot.hold('off')
    plot.grid('on')

# %%
def vis_hyperplane(w, typ='k--'):
    plot.hold('on')

    lim0 = plot.gca().get_xlim()
    lim1 = plot.gca().get_ylim()
    m0, m1 = lim0[0], lim0[1]

    intercept0 = -(w[0] * m0 + w[-1])/w[1]
    intercept1 = -(w[0] * m1 + w[-1])/w[1]
    
    plt1, = plot.plot([m0, m1], [intercept0, intercept1], typ)

    plot.gca().set_xlim(lim0)
    plot.gca().set_ylim(lim1)
    
    plot.hold('off')
    
    return plt1

# %%
plot.figure()

vis_data(x_tra, y_tra, c='r')
#vis_data(x_tes, y_tes, c='b')

plt0 = vis_hyperplane(w0, 'k-.')
plt1 = vis_hyperplane(w, 'k--')
plot.legend([plt0, plt1], [
        'Initial: ${:.2} x_1 + {:.2} x_2 + {:.2} = 0$'.format(*list(w0)),
        'Final: ${:.2} x_1 + {:.2} x_2 + {:.2} = 0$'.format(*list(w))],
           loc='best')

plot.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
tra_er = numpy.sum(numpy.abs(numpy.round(logreg(x_tra, w)) - y_tra)) / numpy.float(len(y_tra))
tes_er = numpy.sum(numpy.abs(numpy.round(logreg(x_tes, w)) - y_tes)) / numpy.float(len(y_tes))

print 'Training error rate {}, Test error rate {}'.format(tra_er, tes_er)
# Out:
# Training error rate 0.0, Test error rate 0.0
